# %% [markdown]
# # Industrial price index
#
# https://data.cso.ie/table/WPM40

# %%
filename = "WPM40.20260127T000132.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(filename).dropna()

# %%
df.head()
# Out:
#                               Statistic Label         Month  \
# 0  Domestic Industrial Price Index (Excl VAT)  2021 January
# 3  Domestic Industrial Price Index (Excl VAT)  2021 January
# 4  Domestic Industrial Price Index (Excl VAT)  2021 January
# 6  Domestic Industrial Price Index (Excl VAT)  2021 January
# 7  Domestic Industrial Price Index (Excl VAT)  2021 January
#
#                       Industry Sector NACE Rev 2                UNIT  \
# 0                             Food products (10)  Base Year 2021=100
# 3                                  Textiles (13)  Base Year 2021=100
# 4                           Wearing apparel (14)  Base Year 2021=100
# 6  Wood and wood products, except furniture (16)  Base Year 2021=100
# 7                  Paper and paper products (17)  Base Year 2021=100
#
#        VALUE
# 0  99.046935
# 3  98.441859
# 4  99.771523
# 6  94.304498
# 7  99.037189

# %%
df["Statistic Label"].unique()
# Out:
# <StringArray>
# ['Domestic Industrial Price Index (Excl VAT)', 'Export Industrial Price Index (Excl VAT)']
# Length: 2, dtype: str

# %%
df["Month"].unique()
# Out:
# <StringArray>
# [  '2021 January',  '2021 February',     '2021 March',     '2021 April',
#        '2021 May',      '2021 June',      '2021 July',    '2021 August',
#  '2021 September',   '2021 October',  '2021 November',  '2021 December',
#    '2022 January',  '2022 February',     '2022 March',     '2022 April',
#        '2022 May',      '2022 June',      '2022 July',    '2022 August',
#  '2022 September',   '2022 October',  '2022 November',  '2022 December',
#    '2023 January',  '2023 February',     '2023 March',     '2023 April',
#        '2023 May',      '2023 June',      '2023 July',    '2023 August',
#  '2023 September',   '2023 October',  '2023 November',  '2023 December',
#    '2024 January',  '2024 February',     '2024 March',     '2024 April',
#        '2024 May',      '2024 June',      '2024 July',    '2024 August',
#  '2024 September',   '2024 October',  '2024 November',  '2024 December',
#    '2025 January',  '2025 February',     '2025 March',     '2025 April',
# ...

# %%
df["Industry Sector NACE Rev 2"]
# Out:
# 0                                      Food products (10)
# 3                                           Textiles (13)
# 4                                    Wearing apparel (14)
# 6           Wood and wood products, except furniture (16)
# 7                           Paper and paper products (17)
#                               ...
# 2990    Fabricated metal products, except machinery an...
# 2992                            Electrical equipment (27)
# 2994      Motor vehicles, trailers and semi-trailers (29)
# 2996                                       Furniture (31)
# 2998                      Mining and quarrying (05 to 09)
# Name: Industry Sector NACE Rev 2, Length: 1680, dtype: str
