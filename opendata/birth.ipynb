# %% [markdown]
# # Birth Rates

# %%
import pandas as pd

# %%
filename="VSA108.20260102T100130.csv"
filename="VSA104.20260102T100128.csv"

# %%
df = pd.read_csv(filename)
all = df[df["NUTS 3 Region"] == "Ireland"]
all = all.dropna()

# %%
all["Statistic Label"].unique()
# Out:
# <StringArray>
# ['Total period of fertility rate', 'Age specific fertility rates']
# Length: 2, dtype: str

# %%
all.plot(x="Year", y="VALUE")
# Out:
# <Axes: xlabel='Year'>
