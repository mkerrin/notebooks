# %% [markdown]
# # Trade and economics

# %%
import pandas as pd
import numpy as np

# %%
# https://data.cso.ie/table/TSA11
filename = "TSA11.20260117T120123.csv"
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#     Statistic Label  Year                  Sector of Activity  \
# 0  Value of Exports  2017  Agriculture and Food (01-03,10-11)
# 1  Value of Exports  2017  Agriculture and Food (01-03,10-11)
# 2  Value of Exports  2017  Agriculture and Food (01-03,10-11)
# 3  Value of Exports  2017  Agriculture and Food (01-03,10-11)
# 4  Value of Exports  2017  Agriculture and Food (01-03,10-11)
#
#     Size of Enterprise          UNIT    VALUE
# 0       Micro (0 to 9)  Euro Million    615.0
# 1     Small (10 to 49)  Euro Million    545.0
# 2   Medium (50 to 249)  Euro Million   1985.0
# 3  Large (250 or more)  Euro Million  14778.0
# 4              Unknown  Euro Million      NaN

# %%
df.dtypes
# Out:
# Statistic Label           str
# Year                    int64
# Sector of Activity        str
# Size of Enterprise        str
# UNIT                      str
# VALUE                 float64
# dtype: object

# %%
df.groupby("Year")["VALUE"].sum()
# Out:
# Year
# 2017     978210.0
# 2018    1086165.0
# 2019    1172079.0
# 2020    1187364.0
# 2021    1299025.0
# 2022    1620034.0
# Name: VALUE, dtype: float64

# %%
df["Sector of Activity"].unique()
# Out:
# <StringArray>
# [                        'Agriculture and Food (01-03,10-11)',
#                       'Chemicals and Pharmaceuticals (20-21)',
#  'Other Manufacturing and Construction (05-09, 12-19, 22-43)',
#                                'Wholesale and Retail (45-47)',
#                                      'Services/other (49-98)',
#                                                     'Unknown',
#                                                 'All sectors']
# Length: 7, dtype: str
